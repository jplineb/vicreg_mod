# %% [markdown]
# # Imports

# %%
import pandas as pd
import os
import shutil
import mapply

mapply.init(
    n_workers=-1,
    chunk_size=100,
    max_chunks_per_worker=8,
    progressbar=False
)

# %% [markdown]
# Purpose of this script is to arrange any dataset into imagenet format. Imagenet format is commonly used for CV benchmarks
#
# This file will assume you have a .csv file with a column "PATH"
#
# TODO: Bake in assumption that user has "Class", "Label" columns

# %%
path_to_ds_file = "/zfs/wficai/chexpert/chexpertchestxrays-u20210408/train_cheXbert.csv"
destination_directory = "/fastscratch/jplineb/chexpert_imagenet"

# %% [markdown]
# # Read DF

# %%
df = pd.read_csv(path_to_ds_file)
df.head()
# Out:
#                                                 Path     Sex  Age  \
# 0  CheXpert-v1.0/train/patient00001/study1/view1_...  Female   68
# 1  CheXpert-v1.0/train/patient00002/study2/view1_...  Female   87
# 2  CheXpert-v1.0/train/patient00002/study1/view1_...  Female   83
# 3  CheXpert-v1.0/train/patient00002/study1/view2_...  Female   83
# 4  CheXpert-v1.0/train/patient00003/study1/view1_...    Male   41
#
#   Frontal/Lateral AP/PA  Enlarged Cardiomediastinum  Cardiomegaly  \
# 0         Frontal    AP                         NaN           NaN
# 1         Frontal    AP                         NaN           1.0
# 2         Frontal    AP                         NaN           NaN
# 3         Lateral   NaN                         NaN           NaN
# 4         Frontal    AP                         NaN           NaN
#
#    Lung Opacity  Lung Lesion  Edema  Consolidation  Pneumonia  Atelectasis  \
# 0           NaN          NaN    NaN            NaN        NaN          NaN
# 1           1.0          NaN   -1.0           -1.0        NaN         -1.0
# 2           1.0          NaN    NaN           -1.0        NaN          NaN
# 3           1.0          NaN    NaN           -1.0        NaN          NaN
# 4           NaN          NaN    1.0            NaN        NaN          NaN
#
#    Pneumothorax  Pleural Effusion  Pleural Other  Fracture  Support Devices  \
# 0           0.0               NaN            NaN       NaN              1.0
# 1           NaN              -1.0            NaN       1.0              NaN
# 2           NaN               NaN            NaN       1.0              NaN
# 3           NaN               NaN            NaN       1.0              NaN
# 4           0.0               NaN            NaN       NaN              NaN
#
#    No Finding
# 0         1.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223414 entries, 0 to 223413
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Path                        223414 non-null  object
#  1   Sex                         223414 non-null  object
#  2   Age                         223414 non-null  int64
#  3   Frontal/Lateral             223414 non-null  object
#  4   AP/PA                       191027 non-null  object
#  5   Enlarged Cardiomediastinum  45191 non-null   float64
#  6   Cardiomegaly                50638 non-null   float64
#  7   Lung Opacity                108503 non-null  float64
#  8   Lung Lesion                 12268 non-null   float64
#  9   Edema                       86512 non-null   float64
#  10  Consolidation               71894 non-null   float64
#  11  Pneumonia                   27556 non-null   float64
#  12  Atelectasis                 69008 non-null   float64
#  13  Pneumothorax                78967 non-null   float64
#  14  Pleural Effusion            133226 non-null  float64
#  15  Pleural Other               6828 non-null    float64
#  16  Fracture                    13140 non-null   float64
#  17  Support Devices             117277 non-null  float64
#  18  No Finding                  21124 non-null   float64
# dtypes: float64(14), int64(1), object(4)
# memory usage: 32.4+ MB

# %% [markdown]
# # Create utility functions

# %%
def generate_destination_directory(row, class_name, dest_dir, split="train"):
    class_label = int(row[class_name])
    dest_path = f"{dest_dir}/{split}/{class_name}/{class_label}"
    return dest_path    

def move_files_from_df(row, origin_col, dest_col):
    # Grab dirs
    origin_path = "/zfs/wficai/chexpert/chexpertchestxrays-u20210408/" + row[origin_col]
    origin_file = os.path.basename(origin_path)
    dest_path = row[dest_col] + origin_file
    # Move files
    ## Make directory if not exists
    dest_dir = os.path.dirname(dest_path)
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)
        
    shutil.copy(origin_path, dest_path)
    
    return None

# %% [markdown]
# # Lets just try one diagnosis

# %% [markdown]
# ## Lung Edema

# %%
## Lung Edema
df.Edema.value_counts()
# Out:
#  1.0    53058
#  0.0    21243
# -1.0    12211
# Name: Edema, dtype: int64

# %%
df_edema  = df[df.Edema.notna()]
df_edema
# Out:
#                                                      Path     Sex  Age  \
# 1       CheXpert-v1.0/train/patient00002/study2/view1_...  Female   87
# 4       CheXpert-v1.0/train/patient00003/study1/view1_...    Male   41
# 16      CheXpert-v1.0/train/patient00009/study1/view1_...    Male   76
# 17      CheXpert-v1.0/train/patient00009/study1/view2_...    Male   76
# 24      CheXpert-v1.0/train/patient00011/study7/view1_...  Female   19
# ...                                                   ...     ...  ...
# 223402  CheXpert-v1.0/train/patient64532/study1/view1_...  Female   52
# 223403  CheXpert-v1.0/train/patient64533/study1/view1_...    Male   75
# 223407  CheXpert-v1.0/train/patient64536/study2/view1_...  Female   61
# 223408  CheXpert-v1.0/train/patient64536/study1/view1_...  Female   61
# 223411  CheXpert-v1.0/train/patient64538/study1/view1_...  Female    0
#
#        Frontal/Lateral AP/PA  Enlarged Cardiomediastinum  Cardiomegaly  \
# 1              Frontal    AP                         NaN           1.0
# 4              Frontal    AP                         NaN           NaN
# 16             Frontal    PA                         NaN           1.0
# 17             Lateral   NaN                         NaN           1.0
# 24             Frontal    AP                         NaN           NaN
# ...                ...   ...                         ...           ...
# 223402         Frontal    AP                         NaN           NaN
# 223403         Frontal    AP                         NaN           1.0
# 223407         Frontal    AP                         NaN           NaN
# 223408         Frontal    AP                         NaN           NaN
# 223411         Frontal    AP                         NaN           NaN
#
#         Lung Opacity  Lung Lesion  Edema  Consolidation  Pneumonia  \
# 1                1.0          NaN   -1.0           -1.0        NaN
# 4                NaN          NaN    1.0            NaN        NaN
# 16               NaN          NaN    0.0            NaN        NaN
# 17               NaN          NaN    0.0            NaN        NaN
# 24               1.0          NaN    0.0            NaN        NaN
# ...              ...          ...    ...            ...        ...
# 223402           NaN          NaN    0.0            0.0        NaN
# 223403           NaN          NaN    1.0            NaN        NaN
# 223407           NaN          NaN    1.0            NaN        NaN
# 223408           NaN          NaN    1.0            NaN        NaN
# 223411           NaN          NaN   -1.0            NaN        NaN
#
#         Atelectasis  Pneumothorax  Pleural Effusion  Pleural Other  Fracture  \
# 1              -1.0           NaN              -1.0            NaN       1.0
# 4               NaN           0.0               NaN            NaN       NaN
# 16              1.0           NaN               NaN            NaN       NaN
# 17              1.0           NaN               NaN            NaN       NaN
# 24              NaN           NaN               NaN            NaN       NaN
# ...             ...           ...               ...            ...       ...
# 223402          NaN           NaN               0.0            NaN       NaN
# 223403          NaN           NaN               1.0            NaN       NaN
# 223407          NaN           NaN               1.0            NaN       NaN
# 223408          1.0           NaN               NaN            NaN       NaN
# 223411          NaN           NaN               NaN            NaN       NaN
#
#         Support Devices  No Finding
# 1                   NaN         NaN
# 4                   NaN         NaN
# 16                  NaN         NaN
# 17                  NaN         NaN
# 24                  1.0         NaN
# ...                 ...         ...
# 223402              1.0         1.0
# 223403              1.0         NaN
# 223407              NaN         NaN
# 223408              1.0         NaN
# 223411              NaN         NaN
#
# [86512 rows x 19 columns]

# %%
# Generate Destination Directories
df_edema["destination_path"] = df_edema.apply(
    generate_destination_directory,
    class_name="Edema",
    dest_dir = destination_directory,
    split="train",
    axis=1
)
# Out:
# /local_scratch/pbs.178989.pbs02/ipykernel_3549893/1713584006.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_edema["destination_path"] = df_edema.apply(

# %%
df_edema
# Out:
#                                                      Path     Sex  Age  \
# 1       CheXpert-v1.0/train/patient00002/study2/view1_...  Female   87
# 4       CheXpert-v1.0/train/patient00003/study1/view1_...    Male   41
# 16      CheXpert-v1.0/train/patient00009/study1/view1_...    Male   76
# 17      CheXpert-v1.0/train/patient00009/study1/view2_...    Male   76
# 24      CheXpert-v1.0/train/patient00011/study7/view1_...  Female   19
# ...                                                   ...     ...  ...
# 223402  CheXpert-v1.0/train/patient64532/study1/view1_...  Female   52
# 223403  CheXpert-v1.0/train/patient64533/study1/view1_...    Male   75
# 223407  CheXpert-v1.0/train/patient64536/study2/view1_...  Female   61
# 223408  CheXpert-v1.0/train/patient64536/study1/view1_...  Female   61
# 223411  CheXpert-v1.0/train/patient64538/study1/view1_...  Female    0
#
#        Frontal/Lateral AP/PA  Enlarged Cardiomediastinum  Cardiomegaly  \
# 1              Frontal    AP                         NaN           1.0
# 4              Frontal    AP                         NaN           NaN
# 16             Frontal    PA                         NaN           1.0
# 17             Lateral   NaN                         NaN           1.0
# 24             Frontal    AP                         NaN           NaN
# ...                ...   ...                         ...           ...
# 223402         Frontal    AP                         NaN           NaN
# 223403         Frontal    AP                         NaN           1.0
# 223407         Frontal    AP                         NaN           NaN
# 223408         Frontal    AP                         NaN           NaN
# 223411         Frontal    AP                         NaN           NaN
#
#         Lung Opacity  Lung Lesion  Edema  Consolidation  Pneumonia  \
# 1                1.0          NaN   -1.0           -1.0        NaN
# 4                NaN          NaN    1.0            NaN        NaN
# 16               NaN          NaN    0.0            NaN        NaN
# 17               NaN          NaN    0.0            NaN        NaN
# 24               1.0          NaN    0.0            NaN        NaN
# ...              ...          ...    ...            ...        ...
# 223402           NaN          NaN    0.0            0.0        NaN
# 223403           NaN          NaN    1.0            NaN        NaN
# 223407           NaN          NaN    1.0            NaN        NaN
# 223408           NaN          NaN    1.0            NaN        NaN
# 223411           NaN          NaN   -1.0            NaN        NaN
#
#         Atelectasis  Pneumothorax  Pleural Effusion  Pleural Other  Fracture  \
# 1              -1.0           NaN              -1.0            NaN       1.0
# 4               NaN           0.0               NaN            NaN       NaN
# 16              1.0           NaN               NaN            NaN       NaN
# 17              1.0           NaN               NaN            NaN       NaN
# 24              NaN           NaN               NaN            NaN       NaN
# ...             ...           ...               ...            ...       ...
# 223402          NaN           NaN               0.0            NaN       NaN
# 223403          NaN           NaN               1.0            NaN       NaN
# 223407          NaN           NaN               1.0            NaN       NaN
# 223408          1.0           NaN               NaN            NaN       NaN
# 223411          NaN           NaN               NaN            NaN       NaN
#
#         Support Devices  No Finding  \
# 1                   NaN         NaN
# 4                   NaN         NaN
# 16                  NaN         NaN
# 17                  NaN         NaN
# 24                  1.0         NaN
# ...                 ...         ...
# 223402              1.0         1.0
# 223403              1.0         NaN
# 223407              NaN         NaN
# 223408              1.0         NaN
# 223411              NaN         NaN
#
#                                          destination_path
# 1       /fastscratch/jplineb/chexpert_imagenet/train/E...
# 4       /fastscratch/jplineb/chexpert_imagenet/train/E...
# 16      /fastscratch/jplineb/chexpert_imagenet/train/E...
# 17      /fastscratch/jplineb/chexpert_imagenet/train/E...
# 24      /fastscratch/jplineb/chexpert_imagenet/train/E...
# ...                                                   ...
# 223402  /fastscratch/jplineb/chexpert_imagenet/train/E...
# 223403  /fastscratch/jplineb/chexpert_imagenet/train/E...
# 223407  /fastscratch/jplineb/chexpert_imagenet/train/E...
# 223408  /fastscratch/jplineb/chexpert_imagenet/train/E...
# 223411  /fastscratch/jplineb/chexpert_imagenet/train/E...
#
# [86512 rows x 20 columns]

# %%
# Move data over to fast_scratch
df_edema.mapply(
    move_files_from_df,
    origin_col = "Path",
    dest_col = "destination_path",
    axis = 1
)
# Out:
#   0%|          | 0/448 [00:00<?, ?it/s]
# 1         None
# 4         None
# 16        None
# 17        None
# 24        None
#           ...
# 223402    None
# 223403    None
# 223407    None
# 223408    None
# 223411    None
# Length: 86512, dtype: object
